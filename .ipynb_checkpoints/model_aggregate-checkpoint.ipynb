# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC 
from sklearn.metrics import classification_report
import numpy as np
import tensorflow
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import load_model
import joblib
from sklearn.metrics import confusion_matrix
import time
from datetime import datetime
import seaborn as sns

# %%
#defined several functions that are repeated processes

# %%
def confusion(predict_algo):
    matrix_arr = confusion_matrix(y_val, predict_algo, labels=target_names)
    values = []
    recall_rows =[0,0,0]
    precision_col = [0,0,0]
    for i in range(3):
        values.append(matrix_arr[i,i])
        recall_rows[0] = recall_rows[0] + matrix_arr[0,i]
        recall_rows[1] = recall_rows[1] + matrix_arr[1,i]
        recall_rows[2] = recall_rows[2] + matrix_arr[2,i]
        precision_col[0] = precision_col[0] + matrix_arr[i,0]
        precision_col[1] = precision_col[1] + matrix_arr[i,1]
        precision_col[2] = precision_col[2] + matrix_arr[i,2]
    return matrix_arr,values,recall_rows,precision_col


def plot_cm(labels, predictions):
    matrix_arr = confusion_matrix(labels, predictions, labels=target_names)
#     values = []
#     recall_rows =[0,0,0]
#     precision_col = [0,0,0]
#     for i in range(3):
#         values.append(matrix_arr[i,i])
#         recall_rows[0] = recall_rows[0] + matrix_arr[0,i]
#         recall_rows[1] = recall_rows[1] + matrix_arr[1,i]
#         recall_rows[2] = recall_rows[2] + matrix_arr[2,i]
#         precision_col[0] = precision_col[0] + matrix_arr[i,0]
#         precision_col[1] = precision_col[1] + matrix_arr[i,1]
#         precision_col[2] = precision_col[2] + matrix_arr[i,2]

    plt.figure(figsize=(5,5))
    sns.heatmap(matrix_arr, annot=True, fmt="d")
    plt.title("Confusion Matrix")
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')

def precision_recall(predict_algo, algo, time):
    matrix_arr, values, recall_rows, precision_col = confusion(predict_algo)
    values_arr = []
    recall_score=[]
    precision_score = []
    for i in range(3):
        try:
            recall_score.append(values[i]/recall_rows[i])
            precision_score.append(values[i]/precision_col[i])
        except:
            print(f'{i}')
    for i in range(3):
        values_arr.append({"model":algo,"output":target_names[i],"precision":precision_score[i],"recall":recall_score[i],
                          "time": time})
    df_matrix = pd.DataFrame(values_arr)
    return df_matrix


def metric_df(model_df):
    stats_df = model_df.describe().transpose()
    model_stats_df = stats_df.drop(['count'], axis=1)
    model_stats_df['metric'] = model_stats_df.index
    cols = list(model_stats_df.columns)
    cols = [cols[-1]] + cols[:-1]
    model_stats_df = model_stats_df[cols]
    model_stats_df.reset_index(drop=True, inplace=True)
    final_df = pd.concat([model_df,model_stats_df], axis=1)
    return final_df

# %%
#created the dataframe from the csv file

# %%
df = pd.read_csv("data/exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
#took a look at the distribution of classifications to note an potential imbalances that would skew the accuracy

# %%
df['koi_disposition'].value_counts()
# Out:
# FALSE POSITIVE    3504
# CONFIRMED         1800
# CANDIDATE         1687
# Name: koi_disposition, dtype: int64

# %%
# Set features. This will also be used as your x values.

# %%
target = df['koi_disposition']
target_names = ['CONFIRMED', 'FALSE POSITIVE', 'CANDIDATE']
data = df.drop('koi_disposition', axis=1)
feature_names = data.columns
data.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
#split the data for testing and validation

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2)
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.2)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 946               0              0              1              0    4.988387
# 3944              0              1              0              0    0.623394
# 1505              0              0              0              0    6.238535
# 2148              0              0              0              0    4.761706
# 5025              0              1              0              0    5.288548
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 946      2.690000e-05    -2.690000e-05   358.233500          0.003690
# 3944     4.100000e-08    -4.100000e-08   131.599128          0.000062
# 1505     2.330000e-06    -2.330000e-06   171.706325          0.000295
# 2148     3.500000e-06    -3.500000e-06   170.335759          0.000572
# 5025     2.470000e-06    -2.470000e-06   135.807213          0.000375
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
#Scaled the data

# %%
X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
X_val_scaled = X_scaler.transform(X_val)

# %%
#created the tree model

# %%
clf = tree.DecisionTreeClassifier()
clf2 = clf.fit(X_train_scaled, y_train)
print(f"Training Data Score: {clf2.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {clf2.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.838248436103664

# %%
#set the params to be tested by the gridsearch, fit the model to the data, and selected the best results

# %%
param_grid = {
    'max_depth': [10,40,80, 90, 100],
    'min_samples_split': [2,4,8, 10, 12],
    'criterion':['gini','entropy'],
    'splitter':['best','random']
}
grid = GridSearchCV(clf, param_grid, verbose=3)

# %%
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] criterion=gini, max_depth=10, min_samples_split=2, splitter=best
# [CV]  criterion=gini, max_depth=10, min_samples_split=2, splitter=best, score=0.879, total=   0.2s
# [CV] criterion=gini, max_depth=10, min_samples_split=2, splitter=best
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV]  criterion=gini, max_depth=10, min_samples_split=2, splitter=best, score=0.895, total=   0.2s
# [CV] criterion=gini, max_depth=10, min_samples_split=2, splitter=best
# [CV]  criterion=gini, max_depth=10, min_samples_split=2, splitter=best, score=0.856, total=   0.1s
# [CV] criterion=gini, max_depth=10, min_samples_split=2, splitter=best
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# ...

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 4, 'splitter': 'best'}
# 0.8780384671337973

# %%
#ran the decision trees model with the best params and benchmarked its time

# %%
t1 = time.perf_counter()
clf3 = tree.DecisionTreeClassifier(criterion='gini', max_depth=10, min_samples_split=10, splitter='best')
clf3 = clf3.fit(X_train_scaled, y_train)
t2 = time.perf_counter()
clf_time = round(t2 - t1,4)

predictions_clf = clf3.predict(X_val_scaled)
print(classification_report(y_val, predictions_clf,
                            target_names=target_names))
clf_report = classification_report(y_val, predictions_clf, target_names=target_names)
# Out:
#                 precision    recall  f1-score   support
#
#      CONFIRMED       0.83      0.73      0.78        71
# FALSE POSITIVE       0.77      0.86      0.81        73
#      CANDIDATE       0.99      0.98      0.98       136
#
#       accuracy                           0.89       280
#      macro avg       0.86      0.86      0.86       280
#   weighted avg       0.89      0.89      0.89       280

# %%
#ran model scores for the datasets

# %%
clf_t_s = clf3.score(X_train_scaled, y_train)
clf_tr_s = clf3.score(X_test_scaled, y_test)
clf_tv_s = clf3.score(X_val_scaled, y_val)
print(f"Training Data Score: {clf_t_s}")
print(f"Testing Data Score: {clf_tr_s}")
print(f"Validation Data Score: {clf_tv_s}")
print(f"CLF Time: {clf_time}")
# Out:
# Training Data Score: 0.9175608011444921
# Testing Data Score: 0.8748882931188561
# Validation Data Score: 0.8857142857142857
# CLF Time: 0.2047

# %%
#created a df to quickview some metrics

# %%
tree_model_df = precision_recall(predictions_clf,"tree_model", clf_time)
tree_stats_df = metric_df(tree_model_df)
tree_stats_df
# Out:
#         model          output  precision    recall    time     metric  \
# 0  tree_model       CONFIRMED   0.768293  0.863014  0.2047  precision
# 1  tree_model  FALSE POSITIVE   0.985185  0.977941  0.2047     recall
# 2  tree_model       CANDIDATE   0.825397  0.732394  0.2047       time
#
#        mean       std       min       25%       50%       75%       max
# 0  0.859625  0.112424  0.768293  0.796845  0.825397  0.905291  0.985185
# 1  0.857783  0.122857  0.732394  0.797704  0.863014  0.920477  0.977941
# 2  0.204700  0.000000  0.204700  0.204700  0.204700  0.204700  0.204700

# %%
#plotted a confusion matrix to see where the model might be failing

# %%
plot_cm(y_val,predictions_clf)

# %%
#created the random forests model

# %%
rf = RandomForestClassifier(n_estimators=100)
rf = rf.fit(X_train_scaled, y_train)
print(f"Training Data Score: {rf.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {rf.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.8873994638069705

# %%
#set the params to be tested by the gridsearch, fit the model to the data, and selected the best results

# %%
rf2 = RandomForestClassifier()
param_grid2 = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [10, 50, 100, 500]
}
grid2 = GridSearchCV(rf2, param_grid2, verbose=3)

# %%
grid2.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# [CV] bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=10
# [CV]  bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=10, score=0.832, total=   0.1s
# [CV] bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=10
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [CV]  bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=10, score=0.841, total=   0.1s
# [CV] bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=10
# [CV]  bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=10, score=0.818, total=   0.1s
# ...

# %%
print(grid2.best_params_)
print(grid2.best_score_)
# Out:
# {'bootstrap': True, 'max_depth': 100, 'max_features': 3, 'min_samples_leaf': 3, 'min_samples_split': 12, 'n_estimators': 50}
# 0.8787514727722971

# %%
#ran the random forests model with the best params

# %%
t3= time.perf_counter()
rf3 = RandomForestClassifier(bootstrap=True, max_depth=90, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=100)
rf3 = rf3.fit(X_train_scaled, y_train)
t4 = time.perf_counter()
rf_time = round(t4 - t3, 4)
predictions_rf = rf3.predict(X_val_scaled)
print(classification_report(y_val, predictions_rf,
                            target_names=target_names))
rf_report = classification_report(y_val, predictions_rf,
                            target_names=target_names)
# Out:
#                 precision    recall  f1-score   support
#
#      CONFIRMED       0.84      0.73      0.78        71
# FALSE POSITIVE       0.83      0.81      0.82        73
#      CANDIDATE       0.93      1.00      0.96       136
#
#       accuracy                           0.88       280
#      macro avg       0.86      0.85      0.85       280
#   weighted avg       0.88      0.88      0.88       280

# %%
#tested the scores of the datasets

# %%
rf_t_s = rf3.score(X_train_scaled, y_train)
rf_tr_s = rf3.score(X_test_scaled, y_test)
rf_tv_s = rf3.score(X_val_scaled, y_val)

print(f"Training Data Score: {rf_t_s}")
print(f"Testing Data Score: {rf_tr_s}")
print(f"Validation Data Score: {rf_tv_s}")

print(f"RF Time: {rf_time}")
# Out:
# Training Data Score: 0.969241773962804
# Testing Data Score: 0.8748882931188561
# Validation Data Score: 0.8821428571428571
# RF Time: 1.2411

# %%
#generated a dataframe to quickview some descriptive statistics

# %%
forest_model_df = precision_recall(predictions_rf, "forest_model", rf_time)
forest_stats_df = metric_df(forest_model_df)
forest_stats_df
# Out:
#           model          output  precision    recall    time     metric  \
# 0  forest_model       CONFIRMED   0.830986  0.808219  1.2411  precision
# 1  forest_model  FALSE POSITIVE   0.925170  1.000000  1.2411     recall
# 2  forest_model       CANDIDATE   0.838710  0.732394  1.2411       time
#
#        mean       std       min       25%       50%      75%      max
# 0  0.864955  0.052290  0.830986  0.834848  0.838710  0.88194  0.92517
# 1  0.846871  0.137926  0.732394  0.770307  0.808219  0.90411  1.00000
# 2  1.241100  0.000000  1.241100  1.241100  1.241100  1.24110  1.24110

# %%
#plotted the confusion matrix to see where the model might be failing

# %%
plot_cm(y_val,predictions_rf)

# %%
#created the k nearest neighbors model, ran it with defaul settings

# %%
train_scores = []
test_scores = []
for k in range(1, 20, 2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_scaled, y_train)
    train_score = knn.score(X_train_scaled, y_train)
    test_score = knn.score(X_test_scaled, y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)
    print(f"k: {k}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")   
    
plt.plot(range(1, 20, 2), train_scores, marker='o')
plt.plot(range(1, 20, 2), test_scores, marker="x")
plt.xlabel("k neighbors")
plt.ylabel("Testing accuracy Score")
plt.show()
# Out:
# k: 1, Train/Test Score: 1.000/0.797
# k: 3, Train/Test Score: 0.915/0.827
# k: 5, Train/Test Score: 0.890/0.836
# k: 7, Train/Test Score: 0.880/0.831
# k: 9, Train/Test Score: 0.875/0.845
# k: 11, Train/Test Score: 0.871/0.834
# k: 13, Train/Test Score: 0.865/0.838
# k: 15, Train/Test Score: 0.858/0.835
# k: 17, Train/Test Score: 0.857/0.838
# k: 19, Train/Test Score: 0.854/0.842

# %%
knn_f = KNeighborsClassifier(n_neighbors=5)
knn_f.fit(X_train_scaled, y_train)
print('k=5 Test Acc: %.3f' % knn.score(X_test_scaled, y_test))
# Out:
# k=5 Test Acc: 0.842

# %%
#set the params to be tested by the gridsearch, fit the model to the data, and selected the best results

# %%
knn = KNeighborsClassifier()
param_grid3 = {
    'algorithm': ['ball_tree', 'kd_tree', 'brute'],
    'leaf_size': [10,20,30],
    'n_jobs': [-1],
    'n_neighbors': [1,3,5,7,9,11,13,14,15,17,19,21,23,25,27,29],
}
grid3 = GridSearchCV(knn, param_grid3, verbose=3)
grid3.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [CV] algorithm=ball_tree, leaf_size=10, n_jobs=-1, n_neighbors=1 .....
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  algorithm=ball_tree, leaf_size=10, n_jobs=-1, n_neighbors=1, score=0.817, total=   8.0s
# [CV] algorithm=ball_tree, leaf_size=10, n_jobs=-1, n_neighbors=1 .....
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    7.9s remaining:    0.0s
# [CV]  algorithm=ball_tree, leaf_size=10, n_jobs=-1, n_neighbors=1, score=0.823, total=   0.3s
# [CV] algorithm=ball_tree, leaf_size=10, n_jobs=-1, n_neighbors=1 .....
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    8.2s remaining:    0.0s
# [CV]  algorithm=ball_tree, leaf_size=10, n_jobs=-1, n_neighbors=1, score=0.801, total=   0.4s
# [CV] algorithm=ball_tree, leaf_size=10, n_jobs=-1, n_neighbors=1 .....
# [CV]  algorithm=ball_tree, leaf_size=10, n_jobs=-1, n_neighbors=1, score=0.811, total=   0.4s
# ...

# %%
print(grid3.best_params_)
print(grid3.best_score_)
# Out:
# {'algorithm': 'ball_tree', 'leaf_size': 10, 'n_jobs': -1, 'n_neighbors': 9}
# 0.8351190447642847

# %%
#ran the model with best params

# %%
t5= time.perf_counter()
knn_f = KNeighborsClassifier(algorithm='ball_tree', leaf_size=10, n_jobs=-1, n_neighbors=5)
knn_f.fit(X_train_scaled, y_train)
t6= time.perf_counter()
knn_time = round(t6 - t5, 4)
predictions_knn = knn_f.predict(X_val_scaled)
print(classification_report(y_val, predictions_knn,
                            target_names=target_names))
knn_report = classification_report(y_val, predictions_knn,
                            target_names=target_names)
# Out:
#                 precision    recall  f1-score   support
#
#      CONFIRMED       0.67      0.55      0.60        71
# FALSE POSITIVE       0.63      0.73      0.68        73
#      CANDIDATE       0.96      0.98      0.97       136
#
#       accuracy                           0.80       280
#      macro avg       0.76      0.75      0.75       280
#   weighted avg       0.80      0.80      0.80       280

# %%
#tested the scores of the datasets

# %%
knn_t_s = knn_f.score(X_train_scaled, y_train)
knn_tr_s = knn_f.score(X_test_scaled, y_test)
knn_tv_s = knn_f.score(X_val_scaled, y_val)

print(f"Training Data Score: {knn_t_s}")
print(f"Testing Data Score: {knn_tr_s}")
print(f"Validation Data Score: {knn_tv_s}")

print(f"KNN Time: {knn_time}")
# Out:
# Training Data Score: 0.8896638054363376
# Testing Data Score: 0.8355674709562109
# Validation Data Score: 0.8035714285714286
# KNN Time: 0.0595

# %%
#created a dataframe to quickview descriptive statistics

# %%
knn_model_df = precision_recall(predictions_knn, "knn_model", knn_time)
knn_stats_df = metric_df(knn_model_df)
knn_stats_df
# Out:
#        model          output  precision    recall    time     metric  \
# 0  knn_model       CONFIRMED   0.630952  0.726027  0.0595  precision
# 1  knn_model  FALSE POSITIVE   0.963768  0.977941  0.0595     recall
# 2  knn_model       CANDIDATE   0.672414  0.549296  0.0595       time
#
#        mean       std       min       25%       50%       75%       max
# 0  0.755711  0.181371  0.630952  0.651683  0.672414  0.818091  0.963768
# 1  0.751088  0.215419  0.549296  0.637662  0.726027  0.851984  0.977941
# 2  0.059500  0.000000  0.059500  0.059500  0.059500  0.059500  0.059500

# %%
#plotted a confusion matrix to see where the model might be failing

# %%
plot_cm(y_val,predictions_knn)

# %%
#created the SVC model

# %%
model = SVC(kernel='linear')
model.fit(X_train_scaled, y_train)
print('Test Acc: %.3f' % model.score(X_test, y_test))
# Out:
# Test Acc: 0.352

# %%
#set the params to be tested by the gridsearch, fit the model to the data, and selected the best results

# %%
param_grid = {'C': [1, 5, 10],
              'gamma': [0.0001, 0.001, 0.01]}
grid4 = GridSearchCV(model, param_grid, verbose=3)

# %%
grid4.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................... C=1, gamma=0.0001, score=0.891, total=   1.1s
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [CV] ................... C=1, gamma=0.0001, score=0.911, total=   1.0s
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.0s remaining:    0.0s
# [CV] ................... C=1, gamma=0.0001, score=0.869, total=   1.0s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.879, total=   1.0s
# [CV] C=1, gamma=0.0001 ...............................................
# ...

# %%
print(grid4.best_params_)
print(grid4.best_score_)
# Out:
# {'C': 10, 'gamma': 0.0001}
# 0.8878707509420147

# %%
#trained the model with best params

# %%
t7= time.perf_counter()
model = SVC(C=5, gamma=0.0001)
model.fit(X_train_scaled, y_train)
t8= time.perf_counter()
svc_time = round(t8 - t7, 4)
predictions_sv = model.predict(X_val_scaled)
print(classification_report(y_val, predictions_sv,
                            target_names=target_names))
sv_report = classification_report(y_val, predictions_sv,
                            target_names=target_names)
# Out:
#                 precision    recall  f1-score   support
#
#      CONFIRMED       0.72      0.44      0.54        71
# FALSE POSITIVE       0.58      0.81      0.68        73
#      CANDIDATE       0.98      0.98      0.98       136
#
#       accuracy                           0.80       280
#      macro avg       0.76      0.74      0.73       280
#   weighted avg       0.81      0.80      0.79       280

# %%
#tested the datasets scores

# %%
sv_t_s = model.score(X_train_scaled, y_train)
sv_tr_s = model.score(X_test_scaled, y_test)
sv_tv_s = model.score(X_val_scaled, y_val)
print(f"Training Data Score: {sv_t_s}")
print(f"Testing Data Score: {sv_tr_s}")
print(f"Validation Data Score: {sv_tv_s}")
print(f"SVC Time: {svc_time}")
# Out:
# Training Data Score: 0.8274320457796852
# Testing Data Score: 0.8230563002680965
# Validation Data Score: 0.7964285714285714
# SVC Time: 1.8521

# %%
#created a quickview descriptive statistics dataframe

# %%
svc_model_df = precision_recall(predictions_sv, "svc_model", svc_time)
svc_stats_df = metric_df(svc_model_df)
svc_stats_df
# Out:
#        model          output  precision    recall    time     metric  \
# 0  svc_model       CONFIRMED   0.584158  0.808219  1.8521  precision
# 1  svc_model  FALSE POSITIVE   0.977941  0.977941  1.8521     recall
# 2  svc_model       CANDIDATE   0.720930  0.436620  1.8521       time
#
#        mean       std       min       25%       50%       75%       max
# 0  0.761010  0.199927  0.584158  0.652544  0.720930  0.849436  0.977941
# 1  0.740927  0.276864  0.436620  0.622419  0.808219  0.893080  0.977941
# 2  1.852100  0.000000  1.852100  1.852100  1.852100  1.852100  1.852100

# %%
#plotted the confusion matrix

# %%
plot_cm(y_val,predictions_sv)

# %%
#converted the string type category labels to a matrix of (3,)

# %%
label_encoder = LabelEncoder()
label_encoder.fit(y_train)

encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)
encoded_y_val = label_encoder.transform(y_val)

y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)
y_val_categorical = to_categorical(encoded_y_val)

# %%
#created the deap learning model with params relevant to the data type

# %%
model2 = Sequential()
model2.add(Dense(units=100, activation='relu', input_dim=40))
model2.add(Dense(units=100, activation='relu'))
model2.add(Dense(units=3, activation='softmax'))
model2.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['categorical_accuracy'])

# %%
#fit the model to run through the epochs

# %%
t9 = time.perf_counter()
model2.fit(
    X_train_scaled,
    y_train_categorical,
    validation_data=(X_test_scaled, y_test_categorical),
    epochs=20,
    shuffle=True,
    verbose=2
)
t10 = time.perf_counter()
deep_time = round(t10 - t9, 4)
# Out:
# Epoch 1/20
# 175/175 - 0s - loss: 0.1579 - categorical_accuracy: 0.9379 - val_loss: 0.3284 - val_categorical_accuracy: 0.8794
# Epoch 2/20
# 175/175 - 0s - loss: 0.1508 - categorical_accuracy: 0.9401 - val_loss: 0.3409 - val_categorical_accuracy: 0.8803
# Epoch 3/20
# 175/175 - 0s - loss: 0.1537 - categorical_accuracy: 0.9428 - val_loss: 0.3371 - val_categorical_accuracy: 0.8740
# Epoch 4/20
# 175/175 - 0s - loss: 0.1400 - categorical_accuracy: 0.9444 - val_loss: 0.3158 - val_categorical_accuracy: 0.8758
# Epoch 5/20
# 175/175 - 0s - loss: 0.1274 - categorical_accuracy: 0.9471 - val_loss: 0.3012 - val_categorical_accuracy: 0.8829
# Epoch 6/20
# 175/175 - 0s - loss: 0.1259 - categorical_accuracy: 0.9472 - val_loss: 0.3249 - val_categorical_accuracy: 0.8722
# Epoch 7/20
# 175/175 - 0s - loss: 0.1240 - categorical_accuracy: 0.9496 - val_loss: 0.3250 - val_categorical_accuracy: 0.8803
# Epoch 8/20
# ...

# %%
#tested loss and accuracy for the model

# %%
model_loss, model_accuracy = model2.evaluate(
    X_val_scaled, y_val_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
print(f"Deep Time: {deep_time}")
# Out:
# 9/9 - 0s - loss: 0.5601 - categorical_accuracy: 0.8571
# Normal Neural Network - Loss: 0.5600782632827759, Accuracy: 0.8571428656578064
# Deep Time: 4.5694

# %%
#generated predictions for the model

# %%
encoded_predictions = model2.predict_classes(X_val_scaled)
prediction_labels = label_encoder.inverse_transform(encoded_predictions)
print(classification_report(y_val, prediction_labels,
                            target_names=target_names))
deep_report = classification_report(y_val, prediction_labels,
                            target_names=target_names)
# Out:
#                 precision    recall  f1-score   support
#
#      CONFIRMED       0.80      0.63      0.71        71
# FALSE POSITIVE       0.70      0.82      0.75        73
#      CANDIDATE       0.98      0.99      0.99       136
#
#       accuracy                           0.86       280
#      macro avg       0.83      0.82      0.82       280
#   weighted avg       0.86      0.86      0.86       280

# %%
#created a quickview dataframe

# %%
deep_model_df = precision_recall(prediction_labels, "deep_model", deep_time)
deep_stats_df = metric_df(deep_model_df)
deep_stats_df
# Out:
#         model          output  precision    recall    time     metric  \
# 0  deep_model       CONFIRMED   0.697674  0.821918  4.5694  precision
# 1  deep_model  FALSE POSITIVE   0.978261  0.992647  4.5694     recall
# 2  deep_model       CANDIDATE   0.803571  0.633803  4.5694       time
#
#        mean       std       min       25%       50%       75%       max
# 0  0.826502  0.141692  0.697674  0.750623  0.803571  0.890916  0.978261
# 1  0.816123  0.179492  0.633803  0.727860  0.821918  0.907282  0.992647
# 2  4.569400  0.000000  4.569400  4.569400  4.569400  4.569400  4.569400

# %%
#plotted the confusion matrix

# %%
plot_cm(y_val,prediction_labels)

# %%
#displayed all scores for the datasets together

# %%
print(f"Training Data Score for Trees: {clf_t_s}")
print(f"Testing Data Score for Trees: {clf_tr_s}")
print(f"Validation Data Score: {clf_tv_s}")

print(f"Training Data Score for Random Forests: {rf_t_s}")
print(f"Testing Data Score for Random Forests: {rf_tr_s}")
print(f"Validation Data Score: {rf_tv_s}")

print(f"Training Data Score for KNN: {knn_t_s}")
print(f"Testing Data Score for KNN: {knn_tr_s}")
print(f"Validation Data Score: {knn_tv_s}")

print(f"Training Data Score for SVC: {sv_t_s}")
print(f"Testing Data Score for SVC: {sv_tr_s}")
print(f"Validation Data Score: {sv_tv_s}")
# Out:
# Training Data Score for Trees: 0.9175608011444921
# Testing Data Score for Trees: 0.8748882931188561
# Validation Data Score: 0.8857142857142857
# Training Data Score for Random Forests: 0.969241773962804
# Testing Data Score for Random Forests: 0.8748882931188561
# Validation Data Score: 0.8821428571428571
# Training Data Score for KNN: 0.8896638054363376
# Testing Data Score for KNN: 0.8355674709562109
# Validation Data Score: 0.8035714285714286
# Training Data Score for SVC: 0.8274320457796852
# Testing Data Score for SVC: 0.8230563002680965
# Validation Data Score: 0.7964285714285714

# %%
#created a dataframe to display model stats for best scores

# %%
dict_stuff = [{'model':'tree', 'train_score':clf_t_s, 'test_score':clf_tr_s,'val_score':clf_tv_s, 'time':clf_time},
{'model':'forest', 'train_score':rf_t_s, 'test_score':rf_tr_s,'val_score':rf_tv_s, 'time':rf_time},
{'model':'knn', 'train_score':knn_t_s, 'test_score':knn_tr_s,'val_score':knn_tv_s, 'time':knn_time},
{'model':'svc', 'train_score':sv_t_s, 'test_score':sv_tr_s,'val_score':sv_tv_s, 'time':svc_time}]
df_scores = pd.DataFrame(dict_stuff)
df_scores
# Out:
#     model  train_score  test_score  val_score    time
# 0    tree     0.917561    0.874888   0.885714  0.2047
# 1  forest     0.969242    0.874888   0.882143  1.2411
# 2     knn     0.889664    0.835567   0.803571  0.0595
# 3     svc     0.827432    0.823056   0.796429  1.8521

# %%
df1 = df_scores.loc[df_scores['train_score'] == df_scores['train_score'].max()]
df1
# Out:
#     model  train_score  test_score  val_score    time
# 1  forest     0.969242    0.874888   0.882143  1.2411

# %%
df2 = df_scores.loc[df_scores['test_score'] == df_scores['test_score'].max()]
df2
# Out:
#     model  train_score  test_score  val_score    time
# 0    tree     0.917561    0.874888   0.885714  0.2047
# 1  forest     0.969242    0.874888   0.882143  1.2411

# %%
df3 = df_scores.loc[df_scores['val_score'] == df_scores['val_score'].max()]
df3
# Out:
#   model  train_score  test_score  val_score    time
# 0  tree     0.917561    0.874888   0.885714  0.2047

# %%
#displayed all reports concatenated

# %%
print("Trees Data")
print(clf_report)
print("---------------------------------------------------------------------------")
print("Forest Data")
print(rf_report)
print("---------------------------------------------------------------------------")
print("KNN Data")
print(knn_report)
print("---------------------------------------------------------------------------")
print("SVC Data")
print(sv_report)
print("---------------------------------------------------------------------------")
print("Deep Learning Data")
print(deep_report)
# Out:
# Trees Data
#                 precision    recall  f1-score   support
#
#      CONFIRMED       0.83      0.73      0.78        71
# FALSE POSITIVE       0.77      0.86      0.81        73
#      CANDIDATE       0.99      0.98      0.98       136
#
#       accuracy                           0.89       280
#      macro avg       0.86      0.86      0.86       280
#   weighted avg       0.89      0.89      0.89       280
#
# ---------------------------------------------------------------------------
# Forest Data
#                 precision    recall  f1-score   support
#
#      CONFIRMED       0.84      0.73      0.78        71
# FALSE POSITIVE       0.83      0.81      0.82        73
#      CANDIDATE       0.93      1.00      0.96       136
#
#       accuracy                           0.88       280
#      macro avg       0.86      0.85      0.85       280
#   weighted avg       0.88      0.88      0.88       280
#
# ...

# %%
#displayed the descriptive statistics all together

# %%
model_combined_df = pd.concat([tree_stats_df, forest_stats_df,knn_stats_df,svc_stats_df,deep_stats_df], ignore_index=True)
model_combined_df
# Out:
#            model          output  precision    recall    time     metric  \
# 0     tree_model       CONFIRMED   0.768293  0.863014  0.2047  precision
# 1     tree_model  FALSE POSITIVE   0.985185  0.977941  0.2047     recall
# 2     tree_model       CANDIDATE   0.825397  0.732394  0.2047       time
# 3   forest_model       CONFIRMED   0.830986  0.808219  1.2411  precision
# 4   forest_model  FALSE POSITIVE   0.925170  1.000000  1.2411     recall
# 5   forest_model       CANDIDATE   0.838710  0.732394  1.2411       time
# 6      knn_model       CONFIRMED   0.630952  0.726027  0.0595  precision
# 7      knn_model  FALSE POSITIVE   0.963768  0.977941  0.0595     recall
# 8      knn_model       CANDIDATE   0.672414  0.549296  0.0595       time
# 9      svc_model       CONFIRMED   0.584158  0.808219  1.8521  precision
# 10     svc_model  FALSE POSITIVE   0.977941  0.977941  1.8521     recall
# 11     svc_model       CANDIDATE   0.720930  0.436620  1.8521       time
# ...
